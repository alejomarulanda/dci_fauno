# %%
# Import libraries
import os
import glob
import pandas as pd
import geopandas as gpd

# %%
root_folder = "D:\\CIAT\\Code\\BID\\dci_fauno"
data_folder = os.path.join(root_folder, "data","risk_calculator")
inputs = os.path.join(data_folder,"inputs")
outputs = os.path.join(data_folder,"outputs")
conf_folder = os.path.join(data_folder,"conf")

years = [2017,2018]
columns_rm = ["NOMBRE_OFICINA","ESTADO","NUMERO_GUIA","TIPO_ORIGEN","NOMBRE_DESTINO"]

# %%
f_raw = os.path.join(inputs,"mob", "download", "mobilization.csv")

df_raw = pd.read_csv(f_raw, encoding = "ISO-8859-1")
print(df_raw.head())
# Out:
# d:\ciat\virtualenv\jupyter\lib\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (3,4,5,6,7,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       AÑO  MES  DIA DEPARTAMENTO_ORIGEN MUNICIPIO_ORIGEN VEREDA_ORIGEN  \
# 0  2017.0  1.0  1.0           SANTANDER         COROMORO  PUEBLO VIEJO
# 1  2017.0  1.0  1.0           SANTANDER         COROMORO       LA MINA
# 2  2017.0  1.0  2.0             GUAINÍA          INÍRIDA       EL COCO
# 3  2017.0  1.0  2.0             GUAINÍA          INÍRIDA       EL COCO
# 4  2017.0  1.0  2.0             GUAINÍA          INÍRIDA       EL COCO
#
#   DEPARTAMENTO_DESTINO MUNICIPIO_DESTINO VEREDA_DESTINO  \
# 0            SANTANDER           CHARALÁ      ESPERANZA
# 1            ANTIOQUIA          RIONEGRO      TABLACITO
# 2              GUAINÍA           INÍRIDA       SAN LOPE
# 3              GUAINÍA           INÍRIDA       SAN LOPE
# 4              GUAINÍA           INÍRIDA       SAN LOPE
#
#              TIPO_DESTINO  ... OVINO HEMBRA MAYORES DE 6 MES  \
# 0  CONCENTRACIÓN GANADERA  ...                           NaN
# 1                  PREDIO  ...                           NaN
# 2     PLANTA DE BENEFICIO  ...                           NaN
# 3     PLANTA DE BENEFICIO  ...                           NaN
# 4     PLANTA DE BENEFICIO  ...                           NaN
#
#    CAPRINO HEMBRA MENOR DE 6 MES  CAPRINO HEMBRA MAYOR DE 6 MES  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CAPRINO MACHO MENOR DE 6 MESE  CAPRINO MACHO MAYOR DE 6 MESE  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    GALLINAS VIVAS  OTROS  LLAMAS  ALPACAS  AVESTRUCES
# 0             NaN    NaN     NaN      NaN         NaN
# 1             NaN    NaN     NaN      NaN         NaN
# 2             NaN    NaN     NaN      NaN         NaN
# 3             NaN    NaN     NaN      NaN         NaN
# 4             NaN    NaN     NaN      NaN         NaN
#
# [5 rows x 61 columns]

# %%
# Creating a SIT field for origin
df_raw["ID_ORIGEN"] = df_raw["DEPARTAMENTO_ORIGEN"] + "_" + df_raw["MUNICIPIO_ORIGEN"] + "_" + df_raw["VEREDA_ORIGEN"]
df_raw["ID_DESTINO"] = df_raw["DEPARTAMENTO_DESTINO"] + "_" + df_raw["MUNICIPIO_DESTINO"] + "_" + df_raw["VEREDA_DESTINO"]

# %%
f_plots = os.path.join(inputs,"plot", "fixed", "plots", "plots.shp")
gdf_p = gpd.read_file(f_plots)
print(gdf_p.head())
# Out:
#     ext_id       lat        lon  animals  year      adm1  \
# 0   400165  5.282530 -71.963700     7470  2019  CASANARE
# 1   400292  5.342888 -71.967508     6673  2019  CASANARE
# 2  1189289  5.220117 -71.931157     1398  2019  CASANARE
# 3  1475236  5.288035 -71.963668     1115  2019  CASANARE
# 4  1259268  5.229343 -71.942858      676  2019  CASANARE
#
#                    adm2       adm3  animals_ma  index_righ adm1_id adm1_name  \
# 0  SAN LUIS DE PALENQUE  ALGODONAL        7470        4243      85  CASANARE
# 1  SAN LUIS DE PALENQUE   JAGUEYES        6673        4243      85  CASANARE
# 2  SAN LUIS DE PALENQUE   JAGUEYES        1398        4243      85  CASANARE
# 3  SAN LUIS DE PALENQUE   JAGUEYES        1115        4243      85  CASANARE
# 4  SAN LUIS DE PALENQUE   JAGUEYES         676        4243      85  CASANARE
#
#   adm2_id             adm2_name   adm3_id     adm3_name          area  \
# 0   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 1   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 2   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 3   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 4   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
#
#                           geometry
# 0  POINT (1234367.895 1076294.221)
# 1  POINT (1233922.710 1082971.885)
# 2  POINT (1238001.442 1069399.934)
# 3  POINT (1234369.374 1076903.407)
# 4  POINT (1236699.896 1070416.464)

# %%
gdf_p["ID_SITIO"] = gdf_p["adm1_name"] + "_" + gdf_p["adm2_name"] + "_" + gdf_p["adm3_name"]
gdf_p.to_csv(os.path.join(inputs,"mob", "download", "plots.csv"), index = False, encoding = "ISO-8859-1")
gdf_p.head()
# Out:
#     ext_id       lat        lon  animals  year      adm1  \
# 0   400165  5.282530 -71.963700     7470  2019  CASANARE
# 1   400292  5.342888 -71.967508     6673  2019  CASANARE
# 2  1189289  5.220117 -71.931157     1398  2019  CASANARE
# 3  1475236  5.288035 -71.963668     1115  2019  CASANARE
# 4  1259268  5.229343 -71.942858      676  2019  CASANARE
#
#                    adm2       adm3  animals_ma  index_righ adm1_id adm1_name  \
# 0  SAN LUIS DE PALENQUE  ALGODONAL        7470        4243      85  CASANARE
# 1  SAN LUIS DE PALENQUE   JAGUEYES        6673        4243      85  CASANARE
# 2  SAN LUIS DE PALENQUE   JAGUEYES        1398        4243      85  CASANARE
# 3  SAN LUIS DE PALENQUE   JAGUEYES        1115        4243      85  CASANARE
# 4  SAN LUIS DE PALENQUE   JAGUEYES         676        4243      85  CASANARE
#
#   adm2_id             adm2_name   adm3_id     adm3_name          area  \
# 0   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 1   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 2   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 3   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 4   85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
#
#                           geometry                                    ID_SITIO
# 0  POINT (1234367.895 1076294.221)  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 1  POINT (1233922.710 1082971.885)  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 2  POINT (1238001.442 1069399.934)  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 3  POINT (1234369.374 1076903.407)  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 4  POINT (1236699.896 1070416.464)  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES

# %%
df_plots = pd.read_csv( os.path.join(inputs,"mob", "download", "plots.csv"), encoding = "ISO-8859-1")
print(df_plots.head())
# Out:
#     ext_id       lat        lon  animals  year      adm1  \
# 0   400165  5.282530 -71.963700     7470  2019  CASANARE
# 1   400292  5.342888 -71.967508     6673  2019  CASANARE
# 2  1189289  5.220117 -71.931157     1398  2019  CASANARE
# 3  1475236  5.288035 -71.963668     1115  2019  CASANARE
# 4  1259268  5.229343 -71.942858      676  2019  CASANARE
#
#                    adm2       adm3  animals_ma  index_righ  adm1_id adm1_name  \
# 0  SAN LUIS DE PALENQUE  ALGODONAL        7470        4243       85  CASANARE
# 1  SAN LUIS DE PALENQUE   JAGUEYES        6673        4243       85  CASANARE
# 2  SAN LUIS DE PALENQUE   JAGUEYES        1398        4243       85  CASANARE
# 3  SAN LUIS DE PALENQUE   JAGUEYES        1115        4243       85  CASANARE
# 4  SAN LUIS DE PALENQUE   JAGUEYES         676        4243       85  CASANARE
#
#    adm2_id             adm2_name   adm3_id     adm3_name          area  \
# 0    85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 1    85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 2    85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 3    85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
# 4    85325  SAN LUIS DE PALENQUE  85325035  LOS JAGUEYES  46475.280446
#
#                                       geometry  \
# 0  POINT (1234367.895185295 1076294.221478757)
# 1  POINT (1233922.710054415 1082971.884993546)
# 2  POINT (1238001.441599487 1069399.933683947)
# 3  POINT (1234369.373575686 1076903.407042494)
# 4  POINT (1236699.896469829 1070416.464083726)
#
#                                      ID_SITIO
# 0  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 1  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 2  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 3  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES
# 4  CASANARE_SAN LUIS DE PALENQUE_LOS JAGUEYES

# %%
for y in [2017.0, 2018.0]:    
    df_y = df_raw[df_raw["AÑO"] == y]
    print("Original: " + str(df_raw.shape[0]) + " Nuevo: " + str(df_y.shape[0]))
    #types_col = dict(gdf_p.dtypes)
    types_col = dict(df_plots.dtypes)
    
    df_new = pd.merge(df_y, df_plots[["ext_id","ID_SITIO"]], left_on="ID_ORIGEN", right_on='ID_SITIO', how='left')    
    print("Join origen: " + str(df_new.shape[0]))
    #df_new["ext_id"] = df_new["ext_id"].astype(types_col["ext_id"])
    #df_new["ext_id"] = df_new["ext_id"].astype(str).str.split('.', expand = True)[0]
    
    df_new = df_new[df_new["ext_id"].notnull()]
    df_new["ext_id"] = df_new["ext_id"].astype(str).str.split('.', expand = True)[0]
    df_new = df_new.rename(columns={"ext_id":"SIT_ORIGEN"})    
    df_new = df_new.drop(['ID_SITIO'], axis=1)
    print("Filtrado not nulls: " + str(df_new.shape[0]))
    
    #df_new = df_new.sample(n = int(df_new.shape[0]*0.2))
    print("Muestra: " + str(df_new.shape[0]))
    
    df_new = pd.merge(df_new, df_plots[["ext_id","ID_SITIO"]], left_on="ID_DESTINO", right_on='ID_SITIO', how='left')
    print("Join destino: " + str(df_new.shape[0]))
    #df_new["ext_id"] = df_new["ext_id"].astype(types_col["ext_id"])
    #df_new["ext_id"] = df_new["ext_id"].astype(int)    
    
    df_new = df_new[df_new["ext_id"].notnull()]
    df_new["ext_id"] = df_new["ext_id"].astype(str).str.split('.', expand = True)[0]
    df_new = df_new.rename(columns={"ext_id":"SIT_DESTINO"})    
    df_new = df_new.drop(['ID_SITIO'], axis=1)
    print("Filtrado not nulls: " + str(df_new.shape[0]))
    
    #df_new = df_new.sample(n = int(df_new.shape[0]*0.15))
    print("Muestra: " + str(df_new.shape[0]))
    
    
    #df_new["SIT_DESTINO"] = df_new["SIT_DESTINO"].astype(str)
    
    print("Guardando")
    print(df_new.head())
    df_new.to_csv(os.path.join(inputs,"mob", "content", str(y) + ".csv"), index = False, encoding = "ISO-8859-1")
# Out:
# Original: 4661357 Nuevo: 1560011
# Join origen: 8617271
# Filtrado not nulls: 7389493
# Muestra: 7389493
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-1c80f65693ad> in <module>
#      19     print("Muestra: " + str(df_new.shape[0]))
#      20
# ---> 21     df_new = pd.merge(df_new, df_plots[["ext_id","ID_SITIO"]], left_on="ID_DESTINO", right_on='ID_SITIO', how='left')
#      22     print("Join destino: " + str(df_new.shape[0]))
#      23     #df_new["ext_id"] = df_new["ext_id"].astype(types_col["ext_id"])
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     691         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     692
# --> 693         result_data = concatenate_block_managers(
#     694             [(self.left._mgr, lindexers), (self.right._mgr, rindexers)],
#     695             axes=[llabels.append(rlabels), join_index],
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\internals\concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      81         else:
#      82             b = make_block(
# ---> 83                 _concatenate_join_units(join_units, concat_axis, copy=copy),
#      84                 placement=placement,
#      85                 ndim=len(axes),
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\internals\concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     311     empty_dtype, upcasted_na = _get_empty_dtype_and_na(join_units)
#     312
# --> 313     to_concat = [
#     314         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     315         for ju in join_units
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\internals\concat.py in <listcomp>(.0)
#     312
#     313     to_concat = [
# --> 314         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     315         for ju in join_units
#     316     ]
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\internals\concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     296         else:
#     297             for ax, indexer in self.indexers.items():
# --> 298                 values = algos.take_nd(values, indexer, axis=ax, fill_value=fill_value)
#     299
#     300         return values
#
# d:\ciat\virtualenv\jupyter\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1752             out = np.empty(out_shape, dtype=dtype, order="F")
#    1753         else:
# -> 1754             out = np.empty(out_shape, dtype=dtype)
#    1755
#    1756     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 16.8 GiB for an array with shape (50, 44994347) and data type float64
